# %% [markdown]
# # Neural Network (NN) - Fashion MNIST
#
# Code by: Alexandre Russi Jr.
# Academic goals
#
# Personal website: [https://www.alexandrerussi.com/](https://www.alexandrerussi.com/)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical, plot_model
from keras.datasets import fashion_mnist
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Trainning and Test Data

# %%
(train_x, train_y), (test_x_img, test_y) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# show the first image of trainning data
plt.figure()
plt.imshow(train_x[0])
plt.colorbar()
plt.grid(False)
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ## Reshape the images (matrices) to vectors

# %%
train_x = train_x.reshape((-1, 784))
test_x = test_x_img.reshape((-1, 784))

# %% [markdown]
# ## MLP Neural Network Models

# %% [markdown]
# ### 3 Layers model

# %%
network_3 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_3.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 28)                21980
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               3712
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# ...
# Total params: 26,982
# Trainable params: 26,982
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6 Layers model

# %%
network_6 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_6.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_6.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 28)                21980
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               3712
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# ...
# Total params: 76,518
# Trainable params: 76,518
# Non-trainable params: 0
# ...

# %% [markdown]
# ### 12 Layers model

# %%
network_12 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_12.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_12.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 28)                21980
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               3712
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# ...

# %% [markdown]
# ## Trainning the NN Model
# 20 epochs and batch_size = 50

# %% [markdown]
# ### 3 Layers

# %%
history_3 = network_3.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 2s 2ms/step - loss: 1.7265 - categorical_accuracy: 0.6432 - val_loss: 0.8923 - val_categorical_accuracy: 0.6938
# Epoch 2/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7472 - categorical_accuracy: 0.7382 - val_loss: 0.8062 - val_categorical_accuracy: 0.7113
# Epoch 3/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6860 - categorical_accuracy: 0.7688 - val_loss: 0.6329 - val_categorical_accuracy: 0.7956
# Epoch 4/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6563 - categorical_accuracy: 0.7824 - val_loss: 0.5844 - val_categorical_accuracy: 0.7985
# Epoch 5/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6436 - categorical_accuracy: 0.7860 - val_loss: 0.7054 - val_categorical_accuracy: 0.7901
# Epoch 6/20
# ...

# %% [markdown]
# ### 6 Layers

# %%
history_6 = network_6.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.9102 - categorical_accuracy: 0.7099 - val_loss: 0.5699 - val_categorical_accuracy: 0.8012
# Epoch 2/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.5302 - categorical_accuracy: 0.8109 - val_loss: 0.5276 - val_categorical_accuracy: 0.8199
# Epoch 3/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.4734 - categorical_accuracy: 0.8275 - val_loss: 0.4708 - val_categorical_accuracy: 0.8317
# Epoch 4/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.4369 - categorical_accuracy: 0.8410 - val_loss: 0.4403 - val_categorical_accuracy: 0.8422
# Epoch 5/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.4198 - categorical_accuracy: 0.8474 - val_loss: 0.4373 - val_categorical_accuracy: 0.8461
# Epoch 6/20
# ...

# %% [markdown]
# ### 12 Layers

# %%
history_12 = network_12.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.6513 - categorical_accuracy: 0.7704 - val_loss: 0.5348 - val_categorical_accuracy: 0.8025
# Epoch 2/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.4784 - categorical_accuracy: 0.8319 - val_loss: 0.4545 - val_categorical_accuracy: 0.8400
# Epoch 3/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.4373 - categorical_accuracy: 0.8441 - val_loss: 0.4255 - val_categorical_accuracy: 0.8499
# Epoch 4/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.4149 - categorical_accuracy: 0.8535 - val_loss: 0.4229 - val_categorical_accuracy: 0.8583
# Epoch 5/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3965 - categorical_accuracy: 0.8609 - val_loss: 0.4239 - val_categorical_accuracy: 0.8475
# Epoch 6/20
# ...

# %% [markdown]
# ## Saving learned weights

# %%
#network.save_weights('nac1_fashion_mnist_weights.h5')

# %% [markdown]
# ## Graphical representation of NN

# %%
plot_model(network_3, show_shapes=True, show_layer_names=False, rankdir="LR")

# %%
plot_model(network_6, show_shapes=True, show_layer_names=False, rankdir="LR")

# %%
plot_model(network_12, show_shapes=True, show_layer_names=False, rankdir="LR")

# %% [markdown]
# ## Evaluating NN with training data

# %% [markdown]
# Creating structure for final table

# %%
model_analysis = {
    'layers': [],
    'accuracy train data': [],
    'loss train data': [],
    'accuracy test data': [],
    'loss test data': []
}

# %% [markdown]
# ### 3 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_3.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss)
print('Acurácia na base de teste: ', train_acc)

n_layer = model_analysis['layers']
n_layer.append(3)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4169 - categorical_accuracy: 0.8511
# Erro na base de teste:  0.4169383645057678
# Acurácia na base de teste:  0.8511333465576172

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_3.history['categorical_accuracy'], label='train')
ax_acc.plot(history_3.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('3 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_3.history['loss'], label='train')
ax_loss.plot(history_3.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('3 Layers Network Loss')
plt.show()

# %% [markdown]
# ### 6 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_6.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss)
print('Acurácia na base de teste: ', train_acc)

n_layer = model_analysis['layers']
n_layer.append(6)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3228 - categorical_accuracy: 0.8843
# Erro na base de teste:  0.32282376289367676
# Acurácia na base de teste:  0.8843166828155518

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_6.history['categorical_accuracy'], label='train')
ax_acc.plot(history_6.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('6 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_6.history['loss'], label='train')
ax_loss.plot(history_6.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('6 Layers Network Loss')
plt.show()

# %% [markdown]
# ### 12 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_12.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss)
print('Acurácia na base de teste: ', train_acc)

n_layer = model_analysis['layers']
n_layer.append(12)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3207 - categorical_accuracy: 0.8840
# Erro na base de teste:  0.32065385580062866
# Acurácia na base de teste:  0.8839666843414307

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_12.history['categorical_accuracy'], label='train')
ax_acc.plot(history_12.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('12 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_12.history['loss'], label='train')
ax_loss.plot(history_12.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('12 Layers Network Loss')
plt.show()

# %% [markdown]
# ## Evaluating NN with test data

# %% [markdown]
# ### 3 Layers

# %%
test_loss, test_acc = network_3.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss)
print('Acurácia na base de teste: ', test_acc)

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4799 - categorical_accuracy: 0.8395
# Erro na base de teste:  0.47989803552627563
# Acurácia na base de teste:  0.8395000100135803

# %% [markdown]
# ### 6 Layers

# %%
test_loss, test_acc = network_6.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss)
print('Acurácia na base de teste: ', test_acc)

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4108 - categorical_accuracy: 0.8625
# Erro na base de teste:  0.41076773405075073
# Acurácia na base de teste:  0.862500011920929

# %% [markdown]
# ### 12 Layers

# %%
test_loss, test_acc = network_12.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss)
print('Acurácia na base de teste: ', test_acc)

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3883 - categorical_accuracy: 0.8640
# Erro na base de teste:  0.3882904648780823
# Acurácia na base de teste:  0.8640000224113464

# %% [markdown]
# ## Data visualization
# Comparing numbers of layers, accuracy and loss between trainning and test data

# %%
model_analysis
# Out:
# {'accuracy test data': [88.4, 88.4, 88.4],
#  'accuracy train data': [85.11, 88.43, 88.4],
#  'layers': [3, 6, 12],
#  'loss test data': [0.48, 0.41, 0.39],
#  'loss train data': [0.42, 0.32, 0.32]}

# %%
df = pd.DataFrame(model_analysis)
df
# Out:
#    layers  accuracy train data  ...  accuracy test data  loss test data
# 0       3                85.11  ...                88.4            0.48
# 1       6                88.43  ...                88.4            0.41
# 2      12                88.40  ...                88.4            0.39
#
# [3 rows x 5 columns]

# %% [markdown]
# ## Classifications and Predictions

# %% [markdown]
# ### Funções para exibir imgs e predições

# %%
# plot image in a grid
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  
  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'
  
  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

# plot the value array    
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot= plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# ### 3 Layers

# %%
prediction_3 = network_3.predict(test_x)

# %%
y_prediction_3 = prediction_3.argmax(axis=1)
print(classification_report(test_y, y_prediction_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81      1000
#            1       0.98      0.95      0.96      1000
#            2       0.62      0.86      0.72      1000
#            3       0.88      0.85      0.87      1000
#            4       0.76      0.62      0.68      1000
#            5       0.96      0.94      0.95      1000
#            6       0.63      0.51      0.57      1000
#            7       0.94      0.93      0.93      1000
#            8       0.97      0.94      0.95      1000
#            9       0.93      0.95      0.94      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with 3 layers")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_3, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_3, test_y)

# %% [markdown]
# ### 6 Layers

# %%
prediction_6 = network_6.predict(test_x)

# %%
y_prediction_6 = prediction_6.argmax(axis=1)
print(classification_report(test_y, y_prediction_6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82      1000
#            1       0.97      0.97      0.97      1000
#            2       0.77      0.77      0.77      1000
#            3       0.85      0.88      0.87      1000
#            4       0.74      0.80      0.77      1000
#            5       0.95      0.95      0.95      1000
#            6       0.67      0.61      0.64      1000
#            7       0.93      0.93      0.93      1000
#            8       0.94      0.96      0.95      1000
#            9       0.95      0.95      0.95      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with 6 layers")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_6, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_6, test_y)

# %% [markdown]
# ### 12 Layers

# %%
prediction_12 = network_12.predict(test_x)

# %%
y_prediction_12 = prediction_12.argmax(axis=1)
print(classification_report(test_y, y_prediction_12))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.75      0.81      1000
#            1       0.99      0.96      0.97      1000
#            2       0.84      0.67      0.75      1000
#            3       0.85      0.90      0.87      1000
#            4       0.73      0.85      0.79      1000
#            5       0.98      0.93      0.95      1000
#            6       0.64      0.72      0.68      1000
#            7       0.93      0.92      0.93      1000
#            8       0.94      0.97      0.96      1000
#            9       0.92      0.97      0.94      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.87      0.86      0.86     10000
# weighted avg       0.87      0.86      0.86     10000

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with 12 layers")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_12, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_12, test_y)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# EN-US
#
# A 3-layer neural network has performed poorly in many ways. Its accuracy value for training and test data was approximately $75\%$. In addition, the final loss value was approximately $0.60$, a very high value. In the section " Classifications and Predictions", it is possible to observe and prove that this model is not optimized.
#
# However, models of neural networks with 6 and 12 layers propagate well. Its final results were very close, with an accuracy of $88\%$ for training and testing data. In addition, the loss for the training and test data resulted in $0.31$ and $0.41$, respectively. Also, the precision, recall and f1-score values ​​are $96\%$, $94\%$ and $95\%$ for 6 layers and $94\%$, $96\%$ and $95\%$ for 12 layers, respectively. Consequently, it is possible to notice that the values ​​are almost equal.
#
# Therefore, in order to consume less computational processing, it is recommended to use neural networks with 6 layers in this problem of Fashion MNIST.

# %% [markdown]
# PT-BR
#
# A rede neural com 3 camadas se desempenhou mal em diversos aspectos. Seu valor de acurácia para os dados de treinamento e teste foram aproximadamente $75\%$. Além disso, o valor final do erro foi aproximadamente $0.60$, um valor altíssimo. Na seção "*Classifications and Predictions*", é possível observar e comprovar que este modelo não está otimizado.
#
# Entretanto, os modelos de redes neurais com 6 e 12 camadas se desempenharam bem. Seus resultados finais foram bem próximos, com uma acurácia de $88\%$ para dados de treinamentos e de testes. Além de que, o erro para os dados de treinamento e teste resultaram em $0.31$ e $0.41$, respectivamente. E também, os valores de precision, recall e f1-score são $96\%$, $94\%$ e $95\%$ para 6 camadas e $94\%$, $96\%$ e $95\%$ para 12 camadas, respectivamente. Logo, é possível notar que os valores são quase iguais.
#
# Sendo assim, para que haja um consumo de processamento computacional menor, é recomendado que se utilize redes neurais com 6 camadas neste problema de Fashion MNIST.
