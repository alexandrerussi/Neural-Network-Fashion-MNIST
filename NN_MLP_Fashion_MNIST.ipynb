# %% [markdown]
# # Neural Network (NN) - Fashion MNIST
#
# Code by: Alexandre Russi Jr.
# Academic goals
#
# Personal website: [https://www.alexandrerussi.com/](https://www.alexandrerussi.com/)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical, plot_model
from keras.datasets import fashion_mnist
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Trainning and Test Data

# %%
(train_x, train_y), (test_x_img, test_y) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# show the first image of trainning data
plt.figure()
plt.imshow(train_x[0])
plt.colorbar()
plt.grid(False)

# %% [markdown]
# ## Reshape the images (matrices) to vectors

# %%
train_x = train_x.reshape((-1, 784))
test_x = test_x_img.reshape((-1, 784))

# %% [markdown]
# ## MLP Neural Network Models

# %% [markdown]
# ### 3 Layers model

# %%
network_3 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_3.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 28)                21980
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               3712
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 26,982
# Trainable params: 26,982
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6 Layers model

# %%
network_6 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_6.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_6.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 28)                21980
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               3712
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 76,518
# Trainable params: 76,518
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 12 Layers model

# %%
network_12 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_12.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_12.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 28)                21980
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               3712
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 175,590
# Trainable params: 175,590
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Trainning the NN Model
# 20 epochs and batch_size = 50

# %% [markdown]
# ### 3 Layers

# %%
history_3 = network_3.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 2s 2ms/step - loss: 1.7858 - categorical_accuracy: 0.6205 - val_loss: 0.8620 - val_categorical_accuracy: 0.6242
# Epoch 2/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7839 - categorical_accuracy: 0.7040 - val_loss: 0.7807 - val_categorical_accuracy: 0.7212
# Epoch 3/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7446 - categorical_accuracy: 0.7146 - val_loss: 0.7546 - val_categorical_accuracy: 0.7036
# Epoch 4/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7438 - categorical_accuracy: 0.7174 - val_loss: 0.8088 - val_categorical_accuracy: 0.7023
# Epoch 5/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7441 - categorical_accuracy: 0.7158 - val_loss: 0.6980 - val_categorical_accuracy: 0.7254
# Epoch 6/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7205 - categorical_accuracy: 0.7224 - val_loss: 0.8327 - val_categorical_accuracy: 0.7065
# Epoch 7/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7052 - categorical_accuracy: 0.7274 - val_loss: 0.7211 - val_categorical_accuracy: 0.7276
# Epoch 8/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6774 - categorical_accuracy: 0.7304 - val_loss: 0.6764 - val_categorical_accuracy: 0.7414
# Epoch 9/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6738 - categorical_accuracy: 0.7325 - val_loss: 0.7113 - val_categorical_accuracy: 0.7334
# Epoch 10/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6881 - categorical_accuracy: 0.7291 - val_loss: 0.7911 - val_categorical_accuracy: 0.6971
# Epoch 11/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6591 - categorical_accuracy: 0.7339 - val_loss: 0.6410 - val_categorical_accuracy: 0.7384
# Epoch 12/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6496 - categorical_accuracy: 0.7369 - val_loss: 0.6831 - val_categorical_accuracy: 0.7358
# Epoch 13/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6330 - categorical_accuracy: 0.7425 - val_loss: 0.6583 - val_categorical_accuracy: 0.7382
# Epoch 14/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6252 - categorical_accuracy: 0.7390 - val_loss: 0.6775 - val_categorical_accuracy: 0.7293
# Epoch 15/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6173 - categorical_accuracy: 0.7431 - val_loss: 0.7875 - val_categorical_accuracy: 0.7260
# Epoch 16/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6054 - categorical_accuracy: 0.7452 - val_loss: 0.6794 - val_categorical_accuracy: 0.7401
# Epoch 17/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6001 - categorical_accuracy: 0.7465 - val_loss: 0.6443 - val_categorical_accuracy: 0.7454
# Epoch 18/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.5851 - categorical_accuracy: 0.7517 - val_loss: 0.6097 - val_categorical_accuracy: 0.7549
# Epoch 19/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.5805 - categorical_accuracy: 0.7532 - val_loss: 0.6023 - val_categorical_accuracy: 0.7525
# Epoch 20/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.5656 - categorical_accuracy: 0.7565 - val_loss: 0.6085 - val_categorical_accuracy: 0.7482

# %% [markdown]
# ### 6 Layers

# %%
history_6 = network_6.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.8191 - categorical_accuracy: 0.7420 - val_loss: 0.5132 - val_categorical_accuracy: 0.8157
# Epoch 2/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.4967 - categorical_accuracy: 0.8227 - val_loss: 0.4587 - val_categorical_accuracy: 0.8379
# Epoch 3/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.4479 - categorical_accuracy: 0.8390 - val_loss: 0.4432 - val_categorical_accuracy: 0.8413
# Epoch 4/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.4225 - categorical_accuracy: 0.8465 - val_loss: 0.4575 - val_categorical_accuracy: 0.8316
# Epoch 5/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3995 - categorical_accuracy: 0.8535 - val_loss: 0.4494 - val_categorical_accuracy: 0.8449
# Epoch 6/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3861 - categorical_accuracy: 0.8596 - val_loss: 0.3913 - val_categorical_accuracy: 0.8580
# Epoch 7/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3744 - categorical_accuracy: 0.8635 - val_loss: 0.3914 - val_categorical_accuracy: 0.8614
# Epoch 8/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3693 - categorical_accuracy: 0.8643 - val_loss: 0.3801 - val_categorical_accuracy: 0.8646
# Epoch 9/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3601 - categorical_accuracy: 0.8675 - val_loss: 0.4083 - val_categorical_accuracy: 0.8512
# Epoch 10/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3524 - categorical_accuracy: 0.8720 - val_loss: 0.3971 - val_categorical_accuracy: 0.8587
# Epoch 11/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3451 - categorical_accuracy: 0.8739 - val_loss: 0.3790 - val_categorical_accuracy: 0.8652
# Epoch 12/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3406 - categorical_accuracy: 0.8748 - val_loss: 0.3780 - val_categorical_accuracy: 0.8675
# Epoch 13/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3341 - categorical_accuracy: 0.8780 - val_loss: 0.4007 - val_categorical_accuracy: 0.8550
# Epoch 14/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3301 - categorical_accuracy: 0.8784 - val_loss: 0.4191 - val_categorical_accuracy: 0.8625
# Epoch 15/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3261 - categorical_accuracy: 0.8802 - val_loss: 0.3803 - val_categorical_accuracy: 0.8669
# Epoch 16/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3203 - categorical_accuracy: 0.8810 - val_loss: 0.3779 - val_categorical_accuracy: 0.8708
# Epoch 17/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3191 - categorical_accuracy: 0.8832 - val_loss: 0.3768 - val_categorical_accuracy: 0.8673
# Epoch 18/20
# 960/960 [==============================] - 3s 4ms/step - loss: 0.3098 - categorical_accuracy: 0.8852 - val_loss: 0.3929 - val_categorical_accuracy: 0.8722
# Epoch 19/20
# 960/960 [==============================] - 3s 4ms/step - loss: 0.3072 - categorical_accuracy: 0.8858 - val_loss: 0.4375 - val_categorical_accuracy: 0.8627
# Epoch 20/20
# 960/960 [==============================] - 3s 3ms/step - loss: 0.3073 - categorical_accuracy: 0.8880 - val_loss: 0.4076 - val_categorical_accuracy: 0.8622

# %% [markdown]
# ### 12 Layers

# %%
history_12 = network_12.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.6635 - categorical_accuracy: 0.7554 - val_loss: 0.5660 - val_categorical_accuracy: 0.7972
# Epoch 2/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.4904 - categorical_accuracy: 0.8262 - val_loss: 0.4515 - val_categorical_accuracy: 0.8388
# Epoch 3/20
# 960/960 [==============================] - 4s 5ms/step - loss: 0.4487 - categorical_accuracy: 0.8423 - val_loss: 0.4509 - val_categorical_accuracy: 0.8354
# Epoch 4/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.4249 - categorical_accuracy: 0.8501 - val_loss: 0.4616 - val_categorical_accuracy: 0.8442
# Epoch 5/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.4020 - categorical_accuracy: 0.8576 - val_loss: 0.4379 - val_categorical_accuracy: 0.8549
# Epoch 6/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3957 - categorical_accuracy: 0.8589 - val_loss: 0.3988 - val_categorical_accuracy: 0.8586
# Epoch 7/20
# 960/960 [==============================] - 4s 5ms/step - loss: 0.3753 - categorical_accuracy: 0.8675 - val_loss: 0.4108 - val_categorical_accuracy: 0.8552
# Epoch 8/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3754 - categorical_accuracy: 0.8675 - val_loss: 0.3985 - val_categorical_accuracy: 0.8624
# Epoch 9/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3628 - categorical_accuracy: 0.8691 - val_loss: 0.4148 - val_categorical_accuracy: 0.8638
# Epoch 10/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3576 - categorical_accuracy: 0.8730 - val_loss: 0.3992 - val_categorical_accuracy: 0.8575
# Epoch 11/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3451 - categorical_accuracy: 0.8772 - val_loss: 0.4139 - val_categorical_accuracy: 0.8558
# Epoch 12/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3524 - categorical_accuracy: 0.8729 - val_loss: 0.3918 - val_categorical_accuracy: 0.8650
# Epoch 13/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3473 - categorical_accuracy: 0.8757 - val_loss: 0.3784 - val_categorical_accuracy: 0.8697
# Epoch 14/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3462 - categorical_accuracy: 0.8774 - val_loss: 0.3942 - val_categorical_accuracy: 0.8581
# Epoch 15/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3376 - categorical_accuracy: 0.8771 - val_loss: 0.4128 - val_categorical_accuracy: 0.8536
# Epoch 16/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3302 - categorical_accuracy: 0.8815 - val_loss: 0.3981 - val_categorical_accuracy: 0.8680
# Epoch 17/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3310 - categorical_accuracy: 0.8808 - val_loss: 0.4004 - val_categorical_accuracy: 0.8621
# Epoch 18/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3212 - categorical_accuracy: 0.8855 - val_loss: 0.3929 - val_categorical_accuracy: 0.8676
# Epoch 19/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3264 - categorical_accuracy: 0.8833 - val_loss: 0.4121 - val_categorical_accuracy: 0.8606
# Epoch 20/20
# 960/960 [==============================] - 5s 5ms/step - loss: 0.3226 - categorical_accuracy: 0.8844 - val_loss: 0.4036 - val_categorical_accuracy: 0.8649

# %% [markdown]
# ## Saving learned weights

# %%
#network.save_weights('nac1_fashion_mnist_weights.h5')

# %% [markdown]
# ## Graphical representation of NN

# %%
plot_model(network_3, show_shapes=True, show_layer_names=False, rankdir="LR")

# %%
plot_model(network_6, show_shapes=True, show_layer_names=False, rankdir="LR")

# %%
plot_model(network_12, show_shapes=True, show_layer_names=False, rankdir="LR")

# %% [markdown]
# ## Evaluating NN with training data

# %% [markdown]
# Creating structure for final table

# %%
model_analysis = {
    'layers': [],
    'accuracy train data': [],
    'loss train data': [],
    'accuracy test data': [],
    'loss test data': []
}

# %% [markdown]
# ### 3 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_3.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss)
print('Acurácia na base de teste: ', train_acc)

n_layer = model_analysis['layers']
n_layer.append(3)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5634 - categorical_accuracy: 0.7571
# Erro na base de teste:  0.5634398460388184
# Acurácia na base de teste:  0.7570666670799255

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_3.history['categorical_accuracy'], label='train')
ax_acc.plot(history_3.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('3 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_3.history['loss'], label='train')
ax_loss.plot(history_3.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('3 Layers Network Loss')
plt.show()

# %% [markdown]
# ### 6 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_6.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss)
print('Acurácia na base de teste: ', train_acc)

n_layer = model_analysis['layers']
n_layer.append(6)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3267 - categorical_accuracy: 0.8800
# Erro na base de teste:  0.3267357051372528
# Acurácia na base de teste:  0.8799999952316284

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_6.history['categorical_accuracy'], label='train')
ax_acc.plot(history_6.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('6 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_6.history['loss'], label='train')
ax_loss.plot(history_6.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('6 Layers Network Loss')
plt.show()

# %% [markdown]
# ### 12 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_12.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss)
print('Acurácia na base de teste: ', train_acc)

n_layer = model_analysis['layers']
n_layer.append(12)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3307 - categorical_accuracy: 0.8843
# Erro na base de teste:  0.3307384252548218
# Acurácia na base de teste:  0.8842999935150146

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_12.history['categorical_accuracy'], label='train')
ax_acc.plot(history_12.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('12 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_12.history['loss'], label='train')
ax_loss.plot(history_12.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('12 Layers Network Loss')
plt.show()

# %% [markdown]
# ## Evaluating NN with test data

# %% [markdown]
# ### 3 Layers

# %%
test_loss, test_acc = network_3.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss)
print('Acurácia na base de teste: ', test_acc)

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(test_acc, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 0s 2ms/step - loss: 0.6242 - categorical_accuracy: 0.7443
# Erro na base de teste:  0.624180257320404
# Acurácia na base de teste:  0.7443000078201294

# %% [markdown]
# ### 6 Layers

# %%
test_loss, test_acc = network_6.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss)
print('Acurácia na base de teste: ', test_acc)

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(test_acc, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4218 - categorical_accuracy: 0.8545
# Erro na base de teste:  0.4218025803565979
# Acurácia na base de teste:  0.8544999957084656

# %% [markdown]
# ### 12 Layers

# %%
test_loss, test_acc = network_12.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss)
print('Acurácia na base de teste: ', test_acc)

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(test_acc, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4350 - categorical_accuracy: 0.8583
# Erro na base de teste:  0.4349510669708252
# Acurácia na base de teste:  0.858299970626831

# %% [markdown]
# ## Data visualization
# Comparing numbers of layers, accuracy and loss between trainning and test data

# %%
model_analysis
# Out:
# {'accuracy test data': [0.74, 0.85, 0.86],
#  'accuracy train data': [0.76, 0.88, 0.88],
#  'layers': [3, 6, 12],
#  'loss test data': [0.62, 0.42, 0.43],
#  'loss train data': [0.56, 0.33, 0.33]}

# %%
df = pd.DataFrame(model_analysis)
df
# Out:
#    layers  accuracy train data  ...  accuracy test data  loss test data
# 0       3                 0.76  ...                0.74            0.62
# 1       6                 0.88  ...                0.85            0.42
# 2      12                 0.88  ...                0.86            0.43
#
# [3 rows x 5 columns]

# %% [markdown]
# ## Classifications and Predictions

# %% [markdown]
# ### Funções para exibir imgs e predições

# %%
# plot image in a grid
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  
  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'
  
  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

# plot the value array    
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot= plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# ### 3 Layers

# %%
prediction_3 = network_3.predict(test_x)

# %%
y_prediction_3 = prediction_3.argmax(axis=1)
print(classification_report(test_y, y_prediction_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.76      1000
#            1       0.98      0.95      0.97      1000
#            2       0.37      0.95      0.54      1000
#            3       0.78      0.86      0.82      1000
#            4       0.45      0.14      0.21      1000
#            5       0.92      0.95      0.94      1000
#            6       0.41      0.13      0.20      1000
#            7       0.95      0.89      0.92      1000
#            8       0.96      0.94      0.95      1000
#            9       0.92      0.96      0.94      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.76      0.74      0.72     10000
# weighted avg       0.76      0.74      0.72     10000

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with 3 layers")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_3, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_3, test_y)

# %% [markdown]
# ### 6 Layers

# %%
prediction_6 = network_6.predict(test_x)

# %%
y_prediction_6 = prediction_6.argmax(axis=1)
print(classification_report(test_y, y_prediction_6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.81      1000
#            1       1.00      0.95      0.97      1000
#            2       0.74      0.77      0.75      1000
#            3       0.84      0.89      0.87      1000
#            4       0.83      0.64      0.72      1000
#            5       0.95      0.96      0.95      1000
#            6       0.62      0.62      0.62      1000
#            7       0.94      0.93      0.94      1000
#            8       0.98      0.94      0.96      1000
#            9       0.94      0.95      0.94      1000
#
#     accuracy                           0.85     10000
#    macro avg       0.86      0.85      0.85     10000
# weighted avg       0.86      0.85      0.85     10000

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with 6 layers")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_6, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_6, test_y)

# %% [markdown]
# ### 12 Layers

# %%
prediction_12 = network_12.predict(test_x)

# %%
y_prediction_12 = prediction_12.argmax(axis=1)
print(classification_report(test_y, y_prediction_12))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81      1000
#            1       0.95      0.97      0.96      1000
#            2       0.72      0.80      0.76      1000
#            3       0.90      0.84      0.87      1000
#            4       0.79      0.76      0.78      1000
#            5       0.96      0.94      0.95      1000
#            6       0.64      0.64      0.64      1000
#            7       0.90      0.95      0.92      1000
#            8       0.96      0.95      0.95      1000
#            9       0.95      0.94      0.95      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with 12 layers")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_12, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_12, test_y)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# EN-US
#
# A 3-layer neural network has performed poorly in many ways. Its accuracy value for training and test data was approximately $0.75$. In addition, the final error value was approximately $0.60$, a very high value. In the section " Classifications and Predictions", it is possible to observe and prove that this model is not optimized.
#
# However, models of neural networks with 6 and 12 layers propagate well. Its final results were very close, with an accuracy of $0.88$ for training and testing data. In addition, the error for the training and test data resulted in $0.31$ and $0.41$, respectively. Also, the precision, recall and f1-score values ​​are $0.96$, $0.94$ and $0.95$ for 6 layers and $0.94$, $0.96$ and $0.95$ for 12 layers, respectively. Consequently, it is possible to notice that the values ​​are almost equal.
#
# Therefore, in order to consume less computational processing, it is recommended to use neural networks with 6 layers in this problem of Fashion MNIST.

# %% [markdown]
# PT-BR
#
# A rede neural com 3 camadas se desempenhou mal em diversos aspectos. Seu valor de acurácia para os dados de treinamento e teste foram aproximadamente $0,75$. Além disso, o valor final do erro foi aproximadamente $0,60$, um valor altíssimo. Na seção "*Classifications and Predictions*", é possível observar e comprovar que este modelo não está otimizado.
#
# Entretanto, os modelos de redes neurais com 6 e 12 camadas se desempenharam bem. Seus resultados finais foram bem próximos, com uma acurácia de $0,88$ para dados de treinamentos e de testes. Além de que, o erro para os dados de treinamento e teste resultaram em $0,31$ e $0,41$, respectivamente. E também, os valores de precision, recall e f1-score são $0.96$, $0.94$ e $0.95$ para 6 camadas e $0.94$, $0.96$ e $0.95$ para 12 camadas, respectivamente. Logo, é possível notar que os valores são quase iguais.
#
# Sendo assim, para que haja um consumo de processamento computacional menor, é recomendado que se utilize redes neurais com 6 camadas neste problema de Fashion MNIST.
