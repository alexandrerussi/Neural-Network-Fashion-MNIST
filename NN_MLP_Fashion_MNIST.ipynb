# %% [markdown]
# # Neural Network (NN) - Fashion MNIST
#
# Code by: Alexandre Russi Jr.
# Academic goals
#
# Personal website: [https://www.alexandrerussi.com/](https://www.alexandrerussi.com/)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical, plot_model
from keras.datasets import fashion_mnist

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Trainning and Test Data

# %%
(train_x, train_y), (test_x_img, test_y) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# show the first image of trainning data
plt.figure()
plt.imshow(train_x[0])
plt.colorbar()
plt.grid(False)

# %% [markdown]
# ## Reshape the images (matrices) to vectors

# %%
train_x = train_x.reshape((-1, 784))
test_x = test_x_img.reshape((-1, 784))

# %% [markdown]
# ## MLP Neural Network Models

# %% [markdown]
# ### 3 Layers model

# %%
network_3 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_3.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 28)                21980
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               3712
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 26,982
# Trainable params: 26,982
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6 Layers model

# %%
network_6 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_6.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_6.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 28)                21980
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               3712
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 76,518
# Trainable params: 76,518
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 12 Layers model

# %%
network_12 = Sequential([
                        Dense(28, activation='relu', input_shape=(784,)),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(128, activation='relu'),
                        Dense(10, activation='softmax')
])

network_12.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['categorical_accuracy']
)

network_12.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 28)                21980
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               3712
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 175,590
# Trainable params: 175,590
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Trainning the NN Model
# 20 epochs and batch_size = 50

# %% [markdown]
# ### 3 Layers

# %%
history_3 = network_3.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 2s 2ms/step - loss: 1.5686 - categorical_accuracy: 0.5156 - val_loss: 0.9366 - val_categorical_accuracy: 0.6284
# Epoch 2/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.9330 - categorical_accuracy: 0.6203 - val_loss: 0.9426 - val_categorical_accuracy: 0.6116
# Epoch 3/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.8659 - categorical_accuracy: 0.6615 - val_loss: 0.7667 - val_categorical_accuracy: 0.7143
# Epoch 4/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7996 - categorical_accuracy: 0.6981 - val_loss: 0.8541 - val_categorical_accuracy: 0.7214
# Epoch 5/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7432 - categorical_accuracy: 0.7121 - val_loss: 0.7149 - val_categorical_accuracy: 0.7243
# Epoch 6/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7369 - categorical_accuracy: 0.7134 - val_loss: 0.8119 - val_categorical_accuracy: 0.6972
# Epoch 7/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.7193 - categorical_accuracy: 0.7238 - val_loss: 0.7485 - val_categorical_accuracy: 0.7147
# Epoch 8/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6983 - categorical_accuracy: 0.7265 - val_loss: 0.7365 - val_categorical_accuracy: 0.7034
# Epoch 9/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6743 - categorical_accuracy: 0.7319 - val_loss: 0.7333 - val_categorical_accuracy: 0.7330
# Epoch 10/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6578 - categorical_accuracy: 0.7361 - val_loss: 0.6651 - val_categorical_accuracy: 0.7417
# Epoch 11/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6447 - categorical_accuracy: 0.7385 - val_loss: 0.6699 - val_categorical_accuracy: 0.7398
# Epoch 12/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6340 - categorical_accuracy: 0.7407 - val_loss: 0.6253 - val_categorical_accuracy: 0.7452
# Epoch 13/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6276 - categorical_accuracy: 0.7394 - val_loss: 0.6579 - val_categorical_accuracy: 0.7355
# Epoch 14/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6459 - categorical_accuracy: 0.7405 - val_loss: 0.6361 - val_categorical_accuracy: 0.7372
# Epoch 15/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6192 - categorical_accuracy: 0.7433 - val_loss: 0.6060 - val_categorical_accuracy: 0.7506
# Epoch 16/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.6020 - categorical_accuracy: 0.7483 - val_loss: 0.6136 - val_categorical_accuracy: 0.7447
# Epoch 17/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.5840 - categorical_accuracy: 0.7510 - val_loss: 0.5972 - val_categorical_accuracy: 0.7567
# Epoch 18/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.5949 - categorical_accuracy: 0.7509 - val_loss: 0.5902 - val_categorical_accuracy: 0.7418
# Epoch 19/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.5633 - categorical_accuracy: 0.7564 - val_loss: 0.6025 - val_categorical_accuracy: 0.7536
# Epoch 20/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.5560 - categorical_accuracy: 0.7567 - val_loss: 0.5921 - val_categorical_accuracy: 0.7389

# %% [markdown]
# ### 6 Layers

# %%
history_6 = network_6.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.8317 - categorical_accuracy: 0.7348 - val_loss: 0.6100 - val_categorical_accuracy: 0.7894
# Epoch 2/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.5131 - categorical_accuracy: 0.8170 - val_loss: 0.5255 - val_categorical_accuracy: 0.8227
# Epoch 3/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.4531 - categorical_accuracy: 0.8377 - val_loss: 0.5060 - val_categorical_accuracy: 0.8183
# Epoch 4/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.4329 - categorical_accuracy: 0.8432 - val_loss: 0.4576 - val_categorical_accuracy: 0.8422
# Epoch 5/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.4088 - categorical_accuracy: 0.8537 - val_loss: 0.4257 - val_categorical_accuracy: 0.8526
# Epoch 6/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3927 - categorical_accuracy: 0.8582 - val_loss: 0.4271 - val_categorical_accuracy: 0.8419
# Epoch 7/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3837 - categorical_accuracy: 0.8612 - val_loss: 0.4057 - val_categorical_accuracy: 0.8552
# Epoch 8/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3718 - categorical_accuracy: 0.8643 - val_loss: 0.4052 - val_categorical_accuracy: 0.8577
# Epoch 9/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3622 - categorical_accuracy: 0.8693 - val_loss: 0.4251 - val_categorical_accuracy: 0.8528
# Epoch 10/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3532 - categorical_accuracy: 0.8724 - val_loss: 0.4153 - val_categorical_accuracy: 0.8578
# Epoch 11/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3505 - categorical_accuracy: 0.8751 - val_loss: 0.3848 - val_categorical_accuracy: 0.8649
# Epoch 12/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3407 - categorical_accuracy: 0.8770 - val_loss: 0.4033 - val_categorical_accuracy: 0.8631
# Epoch 13/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.3373 - categorical_accuracy: 0.8779 - val_loss: 0.3908 - val_categorical_accuracy: 0.8628
# Epoch 14/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3297 - categorical_accuracy: 0.8799 - val_loss: 0.3814 - val_categorical_accuracy: 0.8673
# Epoch 15/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3276 - categorical_accuracy: 0.8806 - val_loss: 0.3920 - val_categorical_accuracy: 0.8648
# Epoch 16/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3222 - categorical_accuracy: 0.8827 - val_loss: 0.3758 - val_categorical_accuracy: 0.8717
# Epoch 17/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3213 - categorical_accuracy: 0.8830 - val_loss: 0.3846 - val_categorical_accuracy: 0.8723
# Epoch 18/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3152 - categorical_accuracy: 0.8857 - val_loss: 0.3924 - val_categorical_accuracy: 0.8676
# Epoch 19/20
# 960/960 [==============================] - 2s 2ms/step - loss: 0.3125 - categorical_accuracy: 0.8842 - val_loss: 0.3961 - val_categorical_accuracy: 0.8663
# Epoch 20/20
# 960/960 [==============================] - 2s 3ms/step - loss: 0.3104 - categorical_accuracy: 0.8862 - val_loss: 0.3904 - val_categorical_accuracy: 0.8680

# %% [markdown]
# ### 12 Layers

# %%
history_12 = network_12.fit(
    train_x,
    to_categorical(train_y),
    epochs = 20,
    batch_size = 50,
    validation_split = 0.2
)
# Out:
# Epoch 1/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.6636 - categorical_accuracy: 0.7643 - val_loss: 0.4677 - val_categorical_accuracy: 0.8303
# Epoch 2/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.4691 - categorical_accuracy: 0.8366 - val_loss: 0.4399 - val_categorical_accuracy: 0.8463
# Epoch 3/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.4300 - categorical_accuracy: 0.8484 - val_loss: 0.4858 - val_categorical_accuracy: 0.8336
# Epoch 4/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.4066 - categorical_accuracy: 0.8554 - val_loss: 0.4242 - val_categorical_accuracy: 0.8597
# Epoch 5/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3863 - categorical_accuracy: 0.8617 - val_loss: 0.4379 - val_categorical_accuracy: 0.8488
# Epoch 6/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3841 - categorical_accuracy: 0.8638 - val_loss: 0.4291 - val_categorical_accuracy: 0.8472
# Epoch 7/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3721 - categorical_accuracy: 0.8660 - val_loss: 0.4221 - val_categorical_accuracy: 0.8600
# Epoch 8/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3592 - categorical_accuracy: 0.8719 - val_loss: 0.3811 - val_categorical_accuracy: 0.8614
# Epoch 9/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3617 - categorical_accuracy: 0.8706 - val_loss: 0.3897 - val_categorical_accuracy: 0.8671
# Epoch 10/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3414 - categorical_accuracy: 0.8775 - val_loss: 0.3935 - val_categorical_accuracy: 0.8648
# Epoch 11/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3396 - categorical_accuracy: 0.8782 - val_loss: 0.3804 - val_categorical_accuracy: 0.8736
# Epoch 12/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3357 - categorical_accuracy: 0.8798 - val_loss: 0.4121 - val_categorical_accuracy: 0.8683
# Epoch 13/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3341 - categorical_accuracy: 0.8797 - val_loss: 0.3632 - val_categorical_accuracy: 0.8730
# Epoch 14/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3183 - categorical_accuracy: 0.8849 - val_loss: 0.4064 - val_categorical_accuracy: 0.8547
# Epoch 15/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3242 - categorical_accuracy: 0.8842 - val_loss: 0.4151 - val_categorical_accuracy: 0.8672
# Epoch 16/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3166 - categorical_accuracy: 0.8875 - val_loss: 0.3688 - val_categorical_accuracy: 0.8751
# Epoch 17/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3111 - categorical_accuracy: 0.8877 - val_loss: 0.4127 - val_categorical_accuracy: 0.8583
# Epoch 18/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3127 - categorical_accuracy: 0.8875 - val_loss: 0.3912 - val_categorical_accuracy: 0.8687
# Epoch 19/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3050 - categorical_accuracy: 0.8907 - val_loss: 0.3803 - val_categorical_accuracy: 0.8795
# Epoch 20/20
# 960/960 [==============================] - 4s 4ms/step - loss: 0.3031 - categorical_accuracy: 0.8915 - val_loss: 0.3929 - val_categorical_accuracy: 0.8741

# %% [markdown]
# ## Saving learned weights

# %%
#network.save_weights('nac1_fashion_mnist_weights.h5')

# %% [markdown]
# ## Graphical representation of NN

# %%
plot_model(network_3, show_shapes=True, show_layer_names=False, rankdir="LR")

# %%
plot_model(network_6, show_shapes=True, show_layer_names=False, rankdir="LR")

# %%
plot_model(network_12, show_shapes=True, show_layer_names=False, rankdir="LR")

# %% [markdown]
# ## Evaluating NN with training data

# %% [markdown]
# Creating structure for final table

# %%
model_analysis = {
    'layers': [],
    'accuracy train data': [],
    'loss train data': [],
    'accuracy test data': [],
    'loss test data': []
}

# %% [markdown]
# ### 3 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_3.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss * 100, '%')
print('Acurácia na base de teste: ', train_acc * 100, '%')

n_layer = model_analysis['layers']
n_layer.append(3)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss * 100, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5584 - categorical_accuracy: 0.7461
# Erro na base de teste:  55.83721995353699 %
# Acurácia na base de teste:  74.61333274841309 %

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_3.history['categorical_accuracy'], label='train')
ax_acc.plot(history_3.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('3 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_3.history['loss'], label='train')
ax_loss.plot(history_3.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('3 Layers Network Loss')
plt.show()

# %% [markdown]
# ### 6 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_6.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss * 100, '%')
print('Acurácia na base de teste: ', train_acc * 100, '%')

n_layer = model_analysis['layers']
n_layer.append(6)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss * 100, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3118 - categorical_accuracy: 0.8868
# Erro na base de teste:  31.179094314575195 %
# Acurácia na base de teste:  88.68333101272583 %

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_6.history['categorical_accuracy'], label='train')
ax_acc.plot(history_6.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('6 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_6.history['loss'], label='train')
ax_loss.plot(history_6.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('6 Layers Network Loss')
plt.show()

# %% [markdown]
# ### 12 Layers - Accuracy and loss

# %%
train_loss, train_acc = network_12.evaluate(
    train_x, 
    to_categorical(train_y)
)
print('Erro na base de teste: ', train_loss * 100, '%')
print('Acurácia na base de teste: ', train_acc * 100, '%')

n_layer = model_analysis['layers']
n_layer.append(12)
model_analysis['layers'] = n_layer

value_accuracy = model_analysis['accuracy train data']
value_accuracy.append(round(train_acc * 100, 2))
model_analysis['accuracy train data'] = value_accuracy

value_loss = model_analysis['loss train data']
value_loss.append(round(train_loss * 100, 2))
model_analysis['loss train data'] = value_loss
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3088 - categorical_accuracy: 0.8923
# Erro na base de teste:  30.882978439331055 %
# Acurácia na base de teste:  89.22833204269409 %

# %%
fig_acc, ax_acc = plt.subplots()
ax_acc.plot(history_12.history['categorical_accuracy'], label='train')
ax_acc.plot(history_12.history['val_categorical_accuracy'], label='validate')
ax_acc.legend(loc='best')
ax_acc.set_xlabel('epoch')
ax_acc.set_ylabel('accuracy')
ax_acc.set_title('12 Layers Network Accuracy')
plt.show()

# %%
fig_loss, ax_loss = plt.subplots()
ax_loss.plot(history_12.history['loss'], label='train')
ax_loss.plot(history_12.history['val_loss'], label='validate')
ax_loss.legend(loc='best')
ax_loss.set_xlabel('epoch')
ax_loss.set_ylabel('loss')
ax_loss.set_title('12 Layers Network Loss')
plt.show()

# %% [markdown]
# ## Evaluating NN with test data

# %% [markdown]
# ### 3 Layers

# %%
test_loss, test_acc = network_3.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss * 100, '%')
print('Acurácia na base de teste: ', test_acc * 100, '%')

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(test_acc * 100, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss * 100, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.6184 - categorical_accuracy: 0.7355
# Erro na base de teste:  61.835408210754395 %
# Acurácia na base de teste:  73.54999780654907 %

# %% [markdown]
# ### 6 Layers

# %%
test_loss, test_acc = network_6.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss * 100, '%')
print('Acurácia na base de teste: ', test_acc * 100, '%')

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(test_acc * 100, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss * 100, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4173 - categorical_accuracy: 0.8626
# Erro na base de teste:  41.734546422958374 %
# Acurácia na base de teste:  86.2600028514862 %

# %% [markdown]
# ### 12 Layers

# %%
test_loss, test_acc = network_12.evaluate(
    test_x, 
    to_categorical(test_y)
)
print('Erro na base de teste: ', test_loss * 100, '%')
print('Acurácia na base de teste: ', test_acc * 100, '%')

value_accuracy = model_analysis['accuracy test data']
value_accuracy.append(round(test_acc * 100, 2))
model_analysis['accuracy test data'] = value_accuracy

value_loss = model_analysis['loss test data']
value_loss.append(round(test_loss * 100, 2))
model_analysis['loss test data'] = value_loss
# Out:
# 313/313 [==============================] - 0s 2ms/step - loss: 0.3946 - categorical_accuracy: 0.8694
# Erro na base de teste:  39.46090638637543 %
# Acurácia na base de teste:  86.94000244140625 %

# %% [markdown]
# ## Data visualization
# Comparing numbers of layers, accuracy and loss between trainning and test data

# %%
model_analysis
# Out:
# {'accuracy test data': [73.55, 86.26, 86.94],
#  'accuracy train data': [74.61, 88.68, 89.23],
#  'layers': [3, 6, 12],
#  'loss test data': [61.84, 41.73, 39.46],
#  'loss train data': [55.84, 31.18, 30.88]}

# %%
df = pd.DataFrame(model_analysis)
df
# Out:
#    layers  accuracy train data  ...  accuracy test data  loss test data
# 0       3                74.61  ...               73.55           61.84
# 1       6                88.68  ...               86.26           41.73
# 2      12                89.23  ...               86.94           39.46
#
# [3 rows x 5 columns]

# %% [markdown]
# ## Classifications and Predictions

# %% [markdown]
# ### Funções para exibir imgs e predições

# %%
# plot image in a grid
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  
  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'
  
  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

# plot the value array    
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot= plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# ### 3 Layers

# %%
prediction_3 = network_3.predict(test_x)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with NN-3")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_3, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_3, test_y)

# %% [markdown]
# ### 6 Layers

# %%
prediction_6 = network_6.predict(test_x)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with NN-3")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_6, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_6, test_y)

# %% [markdown]
# ### 12 Layers

# %%
prediction_12 = network_12.predict(test_x)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
plt.title("Predictions of the first 15 images, with NN-3")
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, prediction_12, test_y, test_x_img)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, prediction_12, test_y)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# EN-US
#
# The 3-layer neural network performed poorly in several ways. Its accuracy value for training and test data was approximately 75%. In addition, the final error value was approximately 65%, a very high value. In the "Classifications and Predictions" section, it is possible to observe and prove that this model is not optimized.
#
# However, the 6 and 12 layer neural network models performed well. Its final results were very close, with an accuracy of 88% for training and test data. In addition to that, the error for the training and test data resulted in 31% and 41%, respectively.
#
# Therefore, for less data processing, it is recommended to use neural networks with 6 layers in this problem of Fashion MNIST.

# %% [markdown]
# PT-BR
#
# A rede neural com 3 camadas se desempenhou mal em diversos aspectos. Seu valor de acurácia para os dados de treinamento e teste foram aproximadamente 75%. Além disso, o valor final do erro foi aproximadamente 65%, um valor altíssimo. Na seção "*Classifications and Predictions*", é possível observar e comprovar que este modelo não está otimizado.
#
# Entretanto, as os modelos de redes neurais com 6 e 12 camadas se desempenharam bem. Seus resultados finais foram bem próximos, com uma acurácia de 88% para dados de treinamentos e de testes. Além de que, o erro para os dados de treinamento e teste resultaram em 31% e 41%, respectivamente.
#
# Sendo assim, para que haja um consumo menor, é recomendado que se utilize redes neurais com 6 camadas neste problema de Fashion MNIST.
